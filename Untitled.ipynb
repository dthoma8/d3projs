# %%
import pandas as pd

# %%
av_data = pd.read_csv("./data/Availability.csv")
av_data.head()
# Out:
#    AO_AVAILABILITYPERCENT  AO_AVAILDAYS  AO_FIELDNMCMDAYS  AO_FIELDNMCSDAYS  \
# 0                0.759728     160162.80          29192.40           8034.00
# 1                0.514801      81247.68          26645.52          35544.72
# 2                0.468397      98745.60          15579.60            228.00
# 3                0.940458      49837.20           3131.28              0.00
# 4                0.731588     154230.48          38713.20              0.00
#
#    AO_POSSIBLEDAYS  AO_TOTALFIELDNADAYS   AO_UPNRDAYS DATASEGMENT  \
# 0        210816.00             37905.60  2.455680e-10         AFA
# 1        157823.52             62418.72  3.984000e+03         AFA
# 2        210816.00             27980.40  2.510160e-10         AFA
# 3         52992.48              3155.28  0.000000e+00         AFA
# 4        210816.00             56585.52  0.000000e+00         AFA
#
#    DEPOTNADAYS EICATEGORY  ...   MC_FIELDNMCMDAYS MC_FIELDNMCSDAYS  \
# 0     12747.60         AF  ...                NaN              NaN
# 1     10173.12         AF  ...                NaN              NaN
# 2     84090.00         AF  ...                NaN              NaN
# 3         0.00         AF  ...                NaN              NaN
# 4         0.00         AF  ...                NaN              NaN
#
#   MC_POSSIBLEDAYS MC_TOTALFIELDNADAYS  MC_UPNRDAYS  MONTH_CHAR  MONTH_NUMBER  \
# 0             NaN                 NaN          NaN         NaN           NaN
# 1             NaN                 NaN          NaN         NaN           NaN
# 2             NaN                 NaN          NaN         NaN           NaN
# 3             NaN                 NaN          NaN         NaN           NaN
# 4             NaN                 NaN          NaN         NaN           NaN
#
#                SCORECARDGROUP    SERVICE    TMS
# 0  Combat Fixed Wing Aviation  Air Force  A-10A
# 1  Combat Fixed Wing Aviation  Air Force  A-10A
# 2  Combat Fixed Wing Aviation  Air Force  A-10A
# 3  Combat Fixed Wing Aviation  Air Force  A-10A
# 4  Combat Fixed Wing Aviation  Air Force  A-10A
#
# [5 rows x 28 columns]

# %%
def data2CsvString(data):
    
    string = ",".join(data.columns.tolist())+"\n"
    for i, row in data.iterrows():
        
        obj = row.astype(str).tolist()
        string=string+",".join(obj[:len(obj)-1])+',"%s"\n'%obj[-1]
        
    return string

def writeCsv(csvstring, fname):
    
    with open("./data/"+fname+".csv", "w") as f:
        f.write(csvstring)
        f.close()

# %%
av_data_string = data2CsvString(av_data)
av_data_string
# Out:
